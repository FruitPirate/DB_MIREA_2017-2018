# %%
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# # Задание 1
#
# Вывести 10 самых больших по размеру треков жанра ROCK и формата MPEG (исоп

# %%
# %%sql
# SELECT *
# FROM tracks
# INNER JOIN genres
# ON tracks.Genreid = genres.Genreid
# INNER JOIN media_types
# ON tracks.MediaTypeid = media_types.MediaTypeid
# WHERE (genres.name = 'Rock') AND (media_types.name = 'MPEG audio file')
# ORDER BY tracks.Bytes DESC
# LIMIT 10;
# Out:
# Done.
# [(1666, 'Dazed And Confused', 137, 1, 1, 'Jimmy Page', 1612329, 52490554, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (620, "Space Truckin'", 50, 1, 1, 'Blackmore/Gillan/Glover/Lord/Paice', 1196094, 39267613, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (1581, 'Dazed And Confused', 127, 1, 1, 'Jimmy Page/Led Zeppelin', 1116734, 36052247, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (2429, "We've Got To Get Together/Jingo", 198, 1, 1, None, 1070027, 34618222, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (2432, 'Funky Piano', 198, 1, 1, None, 934791, 30200730, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (621, 'Going Down / Highway Star', 50, 1, 1, 'Gillan/Glover/Lord/Nix - Blackmore/Paice', 913658, 29846063, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (2427, 'Santana Jam', 197, 1, 1, 'Carlos Santana', 882834, 29207100, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (2565, 'The Sun Road', 208, 1, 1, 'Terry Bozzio, Steve Stevens, Tony Levin', 880640, 29008407, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (1670, 'Whole Lotta Love', 138, 1, 1, 'John Bonham/John Paul Jones/Robert Plant/Willie Dixon', 863895, 28191437, 0.99, 1, 'Rock', 1, 'MPEG audio file'),
#  (622, 'Mistreated (Alternate Version)', 50, 1, 1, 'Blackmore/Coverdale', 854700, 27775442, 0.99, 1, 'Rock', 1, 'MPEG audio file')]

# %% [markdown]
# ## Задание 2
# Вывести названия всех групп, их песен и названия их альбомов для всех треков жанра Рок, приобретенные сотрудниками Microsoft.

# %%
# %%sql
# SELECT artists.name as 'Artist', tracks.Name as 'Song', albums.Title as 'Album'
# FROM artists
# INNER JOIN albums
# ON artists.Artistid = albums.Artistid
# INNER JOIN tracks
# ON albums.Albumid = tracks.Albumid
# INNER JOIN genres
# ON tracks.Genreid = genres.Genreid
# INNER JOIN invoice_items
# ON tracks.Trackid = invoice_items.Trackid
# INNER JOIN invoices
# ON invoice_items.Invoiceid = invoices.Invoiceid
# INNER JOIN customers
# ON invoices.Customerid = customers.Customerid
# WHERE (genres.Name = 'Rock') and (customers.Company = 'Microsoft Corporation')
# ORDER BY artists.name;
# Out:
# Done.
# [('Foo Fighters', 'No Way Back', 'In Your Honor [Disc 1]'),
#  ('Foo Fighters', 'Still', 'In Your Honor [Disc 2]'),
#  ('Foo Fighters', 'Razor', 'In Your Honor [Disc 2]'),
#  ('Foo Fighters', 'My Hero', 'The Colour And The Shape'),
#  ("Guns N' Roses", "Double Talkin' Jive", 'Use Your Illusion I'),
#  ("Guns N' Roses", 'The Garden', 'Use Your Illusion I'),
#  ("Guns N' Roses", "Don't Damn Me", 'Use Your Illusion I'),
#  ("Guns N' Roses", 'Dead Horse', 'Use Your Illusion I')]

# %% [markdown]
# ## Задание 3
# Для каждого набора (жанр, тип медиа) вывести среднюю цену по стоимости трека и общее количество, причем вывести только те наборы, для которых все треку стоят больше 1,5$.

# %%
# %%sql
# SELECT genres.Name as 'Genre', media_types.Name as 'MediaType', AVG(tracks.UnitPrice) as 'Average price', count(tracks.TrackId) as 'Number of tracks'
# FROM genres, media_types
# LEFT JOIN tracks
# ON genres.genreid = tracks.genreid and media_types.MediaTypeId = tracks.MediaTypeId
# GROUP BY genres.Name, media_types.Name
# having MIN(tracks.UnitPrice) > 1.5
# Out:
# Done.
# [('Comedy', 'Protected MPEG-4 video file', 1.9899999999999995, 17),
#  ('Drama', 'Protected MPEG-4 video file', 1.9899999999999978, 64),
#  ('Sci Fi & Fantasy', 'Protected MPEG-4 video file', 1.9900000000000004, 26),
#  ('Science Fiction', 'Protected MPEG-4 video file', 1.9899999999999995, 13),
#  ('TV Shows', 'Protected MPEG-4 video file', 1.990000000000001, 93)]

# %% [markdown]
# ## Задание 4
# Вывести компании, сделавшие максимальное и минимальное число заказов.

# %%
# %%sql
# WITH Name AS(
# SELECT Company, COUNT(Company) AS Quentity
# FROM customers
# JOIN Invoices
# ON customers.CustomerId = invoices.CustomerId
# WHERE Company <> 'None'
# GROUP BY Company)
#
# SELECT *
# FROM Name
# WHERE (SELECT MIN(Quentity) FROM Name) = Quentity
# UNION
# SELECT Company, Quentity
# FROM Name
# WHERE (SELECT MAX(Quentity) FROM Name) = Quentity
# Out:
# Done.
# [('Apple Inc.', 7),
#  ('Banco do Brasil S.A.', 7),
#  ('Embraer - Empresa Brasileira de Aeronáutica S.A.', 7),
#  ('Google Inc.', 7),
#  ('JetBrains s.r.o.', 7),
#  ('Microsoft Corporation', 7),
#  ('Riotur', 7),
#  ('Rogers Canada', 7),
#  ('Telus', 7),
#  ('Woodstock Discos', 7)]

# %% [markdown]
# ## Задание 5
# Для каждой компании вывести общее количестов песен, купленных по жанру поп-музыки

# %%
# %%sql
# SELECT customers.Company as 'Company', COUNT(*) as 'Number of songs'
# FROM customers
# INNER JOIN invoices
# ON customers.CustomerId = invoices.CustomerId
# INNER JOIN invoice_items
# ON invoices.InvoiceId = invoice_items.InvoiceId
# INNER JOIN tracks
# ON invoice_items.TrackId = tracks.TrackId
# INNER JOIN genres
# ON tracks.GenreId = genres.GenreId
# WHERE (genres.Name = 'Pop') and (customers.Company <> 'None')
# GROUP BY customers.Company;
# Out:
# Done.
# [('Embraer - Empresa Brasileira de Aeronáutica S.A.', 2),
#  ('JetBrains s.r.o.', 4)]

# %% [markdown]
# ## Задание 6
# Вывести средний размер альбома в байтах.

# %%
# %%sql
# WITH Albums2 AS (SELECT distinct albums.Title as 'Album', SUM(tracks.Bytes) as "Sum"
# FROM albums
# INNER JOIN tracks
# ON albums.AlbumId = tracks.AlbumId
# GROUP BY albums.title)
#
# SELECT AVG(Sum) as 'Average size'
# FROM Albums2
# Out:
# Done.
# [(338288920.3170029,)]

# %%
# %%sql
# SELECT distinct albums.Title as 'Album', SUM(tracks.Bytes) as "Sum"
# FROM albums
# INNER JOIN tracks
# ON albums.AlbumId = tracks.AlbumId
# GROUP BY albums.title
# Out:
# Done.
# [('...And Justice For All', 129097515),
#  ('20th Century Masters - The Millennium Collection: The Best of Scorpions', 57769571),
#  ('A Copland Celebration, Vol. I', 3211245),
#  ('A Matter of Life and Death', 79242814),
#  ('A Real Dead One', 57420135),
#  ('A Real Live One', 56627422),
#  ('A Soprano Inspired', 5605648),
#  ('A TempestadeTempestade Ou O Livro Dos Dias', 132808486),
#  ('A-Sides', 155903303),
#  ('Ace Of Spades', 89221741),
#  ('Achtung Baby', 109070354),
#  ('Acústico', 143234009),
#  ('Acústico MTV', 149678615),
#  ('Acústico MTV [Live]', 131125132),
#  ('Adams, John: The Chairman Dances', 4310896),
#  ('Adorate Deum: Gregorian Chant from the Proper of the Mass', 4123531),
#  ('Afrociberdelia', 141202355),
#  ('Album Of The Year', 84680215),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 133047696),
#  ('Alcohol Fueled Brewtality Live! [Disc 2]', 47710955),
#  ("All That You Can't Leave Behind", 97471974),
#  ('Allegri: Miserere', 8285941),
#  ('American Idiot', 112030714),
#  ('Angel Dust', 121399095),
#  ('Ao Vivo [IMPORT]', 136614542),
#  ('Appetite for Destruction', 53625668),
#  ('Aquaman', 492670102),
#  ('Are You Experienced?', 117941969),
#  ('Armada: Music from the Courts of England and Spain', 4211495),
#  ('Arquivo II', 83274250),
#  ('Arquivo Os Paralamas Do Sucesso', 119760859),
#  ('As Canções de Eu Tu Eles', 96245397),
#  ('Audioslave', 94304482),
#  ('Axé Bahia 2001', 94671890),
#  ('B-Sides 1980-1990', 117986931),
#  ('BBC Sessions [Disc 1] [Live]', 146214998),
#  ('BBC Sessions [Disc 2] [Live]', 151949261),
#  ('Bach: Goldberg Variations', 2081895),
#  ('Bach: Orchestral Suites Nos. 1 - 4', 3847164),
#  ('Bach: The Brandenburg Concertos', 5064553),
#  ('Bach: The Cello Suites', 2315495),
#  ('Bach: Toccata & Fugue in D Minor', 2649938),
#  ('Bach: Violin Concertos', 3192890),
#  ('Back to Black', 40936903),
#  ('BackBeat Soundtrack', 25479147),
#  ('Balls to the Wall', 5510424),
#  ('Bark at the Moon (Remastered)', 4601224),
#  ('Bartok: Violin & Viola Concertos', 9785346),
#  ('Barulhinho Bom', 113614374),
#  ('Battlestar Galactica (Classic), Season 1', 12872621850),
#  ('Battlestar Galactica, Season 3', 10059916535),
#  ('Battlestar Galactica: The Story So Far', 490750393),
#  ('Beethoven Piano Sonatas: Moonlight & Pastorale', 6318740),
#  ('Beethoven: Symhonies Nos. 5 & 6', 6419730),
#  ("Beethoven: Symphony No. 6 'Pastoral' Etc.", 10887931),
#  ('Berlioz: Symphonie Fantastique', 9173344),
#  ('Beyond Good And Evil', 99756577),
#  ('Big Ones', 144277453),
#  ('Bizet: Carmen Highlights', 2189002),
#  ('Black Album', 122464832),
#  ('Black Sabbath', 74962434),
#  ('Black Sabbath Vol. 4 (Remaster)', 84455260),
#  ('Blizzard of Ozz', 10780422),
#  ('Blood Sugar Sex Magik', 146456747),
#  ('Blue Moods', 146930269),
#  ('Body Count', 104756062),
#  ('Bongo Fury', 80495580),
#  ('Brave New World', 160890112),
#  ('By The Way', 136069681),
#  ('Cafezinho', 102701292),
#  ('Cake: B-Sides and Rarities', 8052374),
#  ('Californication', 111197705),
#  ('Carmina Burana', 2630293),
#  ('Carnaval 2001', 133893131),
#  ('Carried to Dust (Bonus Track Version)', 3644793),
#  ('Carry On', 54019835),
#  ('Cesta Básica', 56866743),
#  ('Charpentier: Divertissements, Airs & Concerts', 1973559),
#  ('Chemical Wedding', 120693874),
#  ('Chill: Brazil (Disc 1)', 123846874),
#  ('Chill: Brazil (Disc 2)', 140063843),
#  ('Chopin: Piano Concertos Nos. 1 & 2', 9160082),
#  ('Chronicle, Vol. 1', 134557073),
#  ('Chronicle, Vol. 2', 147920569),
#  ('Cidade Negra - Hits', 114739223),
#  ('Coda', 64763614),
#  ('Come Taste The Band', 73233880),
#  ('Compositores', 117463121),
#  ('Contraband', 111577197),
#  ('Core', 105100844),
#  ('Cássia Eller - Coleção Sem Limite [Disc 2]', 112393534),
#  ('Cássia Eller - Sem Limite [Disc 1]', 115325581),
#  ('Da Lama Ao Caos', 101058439),
#  ('Dance Of Death', 163368433),
#  ('Dark Side Of The Moon', 84141906),
#  ('Deep Purple In Rock', 82499584),
#  ('Deixa Entrar', 94544004),
#  ('Demorou...', 87446874),
#  ('Diary of a Madman (Remastered)', 5179599),
#  ('Diver Down', 61844309),
#  ('Djavan Ao Vivo - Vol. 02', 119200009),
#  ('Djavan Ao Vivo - Vol. 1', 120692024),
#  ('Duos II', 2775071),
#  ('Elgar: Cello Concerto & Vaughan Williams: Fantasias', 7865479),
#  ('Elis Regina-Minha História', 101224351),
#  ('Emergency On Planet Earth', 111603549),
#  ('English Renaissance', 3464564),
#  ('Every Kind of Light', 6694458),
#  ('Faceless', 93120233),
#  ('Facelift', 105527170),
#  ('Fauré: Requiem, Ravel: Pavane & Others', 4314850),
#  ('Fear Of The Dark', 140750126),
#  ('Fireball', 77349498),
#  ('For Those About To Rock We Salute You', 78270414),
#  ('Frank', 49649864),
#  ('From The Muddy Banks Of The Wishkah [Live]', 105880121),
#  ('Garage Inc. (Disc 1)', 128964995),
#  ('Garage Inc. (Disc 2)', 138886953),
#  ('Get Born', 95250956),
#  ('Great Opera Choruses', 4498583),
#  ("Great Performances - Barber's Adagio and Other Romantic Favorites for Strings", 9585597),
#  ('Great Recordings of the Century - Mahler: Das Lied von der Erde', 3700206),
#  ('Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder', 4307907),
#  ("Great Recordings of the Century: Paganini's 24 Caprices", 4371533),
#  ('Greatest Hits', 495425241),
#  ('Greatest Hits I', 114335685),
#  ('Greatest Hits II', 149261240),
#  ('Greatest Kiss', 149946834),
#  ('Green', 80896316),
#  ('Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 4298769),
#  ('Górecki: Symphony No. 3', 9273123),
#  ('Handel: Music for the Royal Fireworks (Original Version 1749)', 2193734),
#  ('Handel: The Messiah (Highlights)', 9553140),
#  ('Haydn: Symphonies 99 - 104', 10085867),
#  ('Heart of the Night', 115736456),
#  ('Heroes, Season 1', 11781321607),
#  ('Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 8547876),
#  ('Hot Rocks, 1964-1971 (Disc 1)', 75476921),
#  ('House of Pain', 130805628),
#  ('Houses Of The Holy', 80150891),
#  ('How To Dismantle An Atomic Bomb', 96520629),
#  ('IV', 83590115),
#  ('In Step', 80989834),
#  ('In Through The Out Door', 84008603),
#  ('In Your Honor [Disc 1]', 78457964),
#  ('In Your Honor [Disc 2]', 85551716),
#  ('Instant Karma: The Amnesty International Campaign to Save Darfur', 83470311),
#  ('International Superhits', 119788040),
#  ('Into The Light', 118307401),
#  ('Iron Maiden', 58750013),
#  ('J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 4744929),
#  ('Jagged Little Pill', 113150359),
#  ('Jorge Ben Jor 25 Anos', 151540639),
#  ('Jota Quest-1995', 100308973),
#  ('Judas 0: B-Sides and Rarities', 137555510),
#  ("Kill 'Em All", 100245858),
#  ('Killers', 55794923),
#  ('King For A Day Fool For A Lifetime', 118212457),
#  ("Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 126524633),
#  ('Koyaanisqatsi (Soundtrack from the Motion Picture)', 3305164),
#  ('LOST, Season 4', 7708725642),
#  ('Led Zeppelin I', 88052688),
#  ('Led Zeppelin II', 82162546),
#  ('Led Zeppelin III', 84966260),
#  ('Let There Be Rock', 80239024),
#  ("Liszt - 12 Études D'Execution Transcendante", 2229617),
#  ('Live After Death', 139907931),
#  ('Live At Donington 1992 (Disc 1)', 74579108),
#  ('Live At Donington 1992 (Disc 2)', 86957380),
#  ('Live On Two Legs [Live]', 140058315),
#  ('Live [Disc 1]', 108244969),
#  ('Live [Disc 2]', 97154716),
#  ('Living After Midnight', 129913886),
#  ('Load', 154914475),
#  ('Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3', 16454937),
#  ('Lost, Season 1', 5280909854),
#  ('Lost, Season 2', 12344960921),
#  ('Lost, Season 3', 13917603291),
#  ('Lulu Santos - RCA 100 Anos De Música - Álbum 01', 104282154),
#  ('Lulu Santos - RCA 100 Anos De Música - Álbum 02', 109759314),
#  ('MK III The Final Concerts [Disc 1]', 113550767),
#  ('Machine Head', 73876920),
#  ('Mais Do Mesmo', 136794032),
#  ('Maquinarama', 105733213),
#  ('Mascagni: Cavalleria Rusticana', 4001276),
#  ('Master Of Puppets', 107305130),
#  ("Mendelssohn: A Midsummer Night's Dream", 6497867),
#  ('Meus Momentos', 96931436),
#  ('Mezmerize', 71400857),
#  ('Miles Ahead', 101204943),
#  ('Milton Nascimento Ao Vivo', 92338500),
#  ('Minas', 101854704),
#  ('Minha Historia', 261227821),
#  ('Minha História', 110075838),
#  ('Misplaced Childhood', 81160939),
#  ("Monteverdi: L'Orfeo", 1189062),
#  ('Morning Dance', 82890414),
#  ('Motley Crue Greatest Hits', 144987965),
#  ('Mozart Gala: Famous Arias', 2861468),
#  ('Mozart: Chamber Music', 3665114),
#  ('Mozart: Symphonies Nos. 40 & 41', 6173269),
#  ('Mozart: Wind Concertos', 6474980),
#  ('Muso Ko', 9471298),
#  ('My Generation - The Very Best Of The Who', 150116941),
#  ('My Way: The Best Of Frank Sinatra [Disc 1]', 147852428),
#  ('Na Pista', 85053585),
#  ('Nevermind', 83252407),
#  ('New Adventures In Hi-Fi', 129305697),
#  ('News Of The World', 76882533),
#  ('Nielsen: The Six Symphonies', 4834785),
#  ('No More Tears (Remastered)', 11665354),
#  ('No Prayer For The Dying', 42457163),
#  ('No Security', 133708206),
#  ('O Samba Poconé', 90000109),
#  ('Olodum', 100151401),
#  ('One By One', 107772817),
#  ('Original Soundtracks 1', 114459497),
#  ('Os Cães Ladram Mas A Caravana Não Pára', 97909484),
#  ('Out Of Exile', 104821979),
#  ('Out Of Time', 87381548),
#  ('Outbreak', 113885807),
#  ('Pachelbel: Canon & Gigue', 4438393),
#  ('Palestrina: Missa Papae Marcelli & Allegri: Miserere', 4244149),
#  ("Pavarotti's Opera Made Easy", 2920890),
#  ('Pearl Jam', 97603532),
#  ('Physical Graffiti [Disc 1]', 76849821),
#  ('Physical Graffiti [Disc 2]', 85541156),
#  ('Piece Of Mind', 44065796),
#  ('Plays Metallica By Four Cellos', 87412645),
#  ('Pop', 118609894),
#  ('Powerslave', 72902401),
#  ('Prenda Minha', 126323002),
#  ('Presence', 87610252),
#  ('Prokofiev: Romeo & Juliet', 4519239),
#  ('Prokofiev: Symphony No.1', 4195542),
#  ('Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 4072205),
#  ('Puccini: Madama Butterfly - Highlights', 4588197),
#  ('Purcell: Music for the Queen Mary', 2365930),
#  ('Purcell: The Fairy Queen', 5987695),
#  ('Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]', 152552513),
#  ('Purpendicular', 122807038),
#  ('Quanta Gente Veio Ver (Live)', 130931619),
#  ('Quanta Gente Veio ver--Bônus De Carnaval', 30732325),
#  ('Quiet Songs', 8833100),
#  ('Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 177192885),
#  ('Rattle And Hum', 141951823),
#  ('Raul Seixas', 93307182),
#  ('ReLoad', 149190035),
#  ('Realize', 11361561),
#  ('Respighi:Pines of Rome', 4718950),
#  ('Restless and Wild', 14613294),
#  ('Retrospective I (1974-1980)', 149419518),
#  ('Revelations', 113423840),
#  ('Ride The Lightning', 93238526),
#  ('Riot Act', 106924349),
#  ('Rock In Rio [CD1]', 135482676),
#  ('Rock In Rio [CD2]', 143408475),
#  ('Roda De Funk', 137980204),
#  ('Rotten Apples: Greatest Hits', 145784788),
#  ('SCRIABIN: Vers la flamme', 3819535),
#  ('Sambas De Enredo 2001', 147338037),
#  ('Santana - As Years Go By', 141740145),
#  ('Santana Live', 130663552),
#  ('Scheherazade', 8916313),
#  ("Schubert: The Late String Quartets & String Quintet (3 CD's)", 2283131),
#  ('Seek And Shall Find: More Of The Best (1963-1981)', 114325206),
#  ('Serie Sem Limite (Disc 1)', 86432811),
#  ('Serie Sem Limite (Disc 2)', 94848523),
#  ('Seventh Son of a Seventh Son', 63424008),
#  ('Sex Machine', 139414030),
#  ('Sibelius: Finlandia', 5908455),
#  ('Sir Neville Marriner: A Celebration', 5760129),
#  ('Slaves And Masters', 91649032),
#  ('Somewhere in Time', 74047907),
#  ('South American Getaway', 4781384),
#  ('Sozinho Remix Ao Vivo', 31892213),
#  ('Speak of the Devil', 67857091),
#  ('St. Anger', 147068291),
#  ('Stormbringer', 71858726),
#  ('Strauss: Waltzes', 8610225),
#  ('Supernatural', 149313144),
#  ('Surfing with the Alien (Remastered)', 38173188),
#  ('Synkronized', 106455339),
#  ('Szymanowski: Piano Works, Vol. 1', 5548755),
#  ('Tangents', 132137612),
#  ("Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 6965201),
#  ('Tchaikovsky: The Nutcracker', 5184289),
#  ('Temple of the Dog', 56198102),
#  ('Ten', 104695769),
#  ('The Battle Rages On', 98191426),
#  ('The Beast Live', 82463322),
#  ('The Best Of 1980-1990', 129096055),
#  ('The Best Of Billy Cobham', 88541978),
#  ('The Best Of Buddy Guy - The Millenium Collection', 86487534),
#  ('The Best Of Men At Work', 85500115),
#  ('The Best Of R.E.M.: The IRS Years', 117826871),
#  ('The Best Of Van Halen, Vol. I', 141986954),
#  ('The Best of Beethoven', 5817216),
#  ('The Best of Ed Motta', 112370144),
#  ('The Colour And The Shape', 91890388),
#  ('The Cream Of Clapton', 144088173),
#  ('The Doors', 87361988),
#  ('The Essential Miles Davis [Disc 1]', 149696800),
#  ('The Essential Miles Davis [Disc 2]', 144644433),
#  ('The Final Concerts (Disc 2)', 121776327),
#  ('The Last Night of the Proms', 4124707),
#  ('The Number of The Beast', 41455547),
#  ('The Office, Season 1', 1610359572),
#  ('The Office, Season 2', 5711964665),
#  ('The Office, Season 3', 7652731262),
#  ('The Police Greatest Hits', 117974705),
#  ('The Real Thing', 109111648),
#  ('The Return Of The Space Cowboy', 132203348),
#  ('The Singles', 127661828),
#  ('The Song Remains The Same (Disc 1)', 95604844),
#  ('The Song Remains The Same (Disc 2)', 99291329),
#  ('The Ultimate Relexation Album', 6458501),
#  ('The World of Classical Favourites', 7761104),
#  ('The X Factor', 170731183),
#  ('Transmission', 97161979),
#  ('Tribute', 142287484),
#  ('UB40 The Best Of - Volume Two [UK]', 117653648),
#  ('Un-Led-Ed', 5126563),
#  ('Unplugged', 269316083),
#  ('Unplugged [Live]', 111923202),
#  ("Up An' Atom", 151386329),
#  ('Use Your Illusion I', 77516317),
#  ('Use Your Illusion II', 148934478),
#  ('Van Halen', 69777244),
#  ('Van Halen III', 127843250),
#  ("Vault: Def Leppard's Greatest Hits", 143600342),
#  ('Vinicius De Moraes', 107759637),
#  ('Vinícius De Moraes - Sem Limite', 108585855),
#  ('Virtual XI', 127800455),
#  ('Vivaldi: The Four Seasons', 3347810),
#  ('Volume Dois', 113158130),
#  ('Voodoo Lounge', 122956410),
#  ('Vozes do MPB', 93875129),
#  ('Vs.', 91185398),
#  ('Wagner: Favourite Overtures', 3114209),
#  ('Walking Into Clarksdale', 119366163),
#  ('War', 83669390),
#  ('Warner 25 Anos', 94682869),
#  ('Weill: The Seven Deadly Sins', 6129146),
#  ('Worlds', 4292028),
#  ('Zooropa', 99289287),
#  ('[1997] Black Light Syndrome', 133288778)]

# %%
# Out:
# Done.
# [('Comedy', 'Protected MPEG-4 video file', 1.9899999999999995, 17),
#  ('Drama', 'Protected MPEG-4 video file', 1.9899999999999978, 64),
#  ('Sci Fi & Fantasy', 'Protected MPEG-4 video file', 1.9900000000000004, 26),
#  ('Science Fiction', 'Protected MPEG-4 video file', 1.9899999999999995, 13),
#  ('TV Shows', 'Protected MPEG-4 video file', 1.990000000000001, 93)]
